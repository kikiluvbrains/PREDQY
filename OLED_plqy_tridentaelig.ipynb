# %%
import pandas as pd

# Specify the path to your CSV file
file_path = "/home/kinkini/plqy/Tridentate ligands on Iridium f7d3712466fd4a459d59e02eeee23428.csv"

# Use pandas to read the CSV file
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
print(data.head())
# Out:
#      entry                                           SMILES 1  \
# 0   ELOYIP                                                NaN
# 1   ELOZAI                                                NaN
# 2   ELOZEM                                                NaN
# 3  ELOZZ1M   CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(F)(F)F)c5)C
# 4  ELOZZ1P  FC(F)(F)c1cc(N(C2=[Ir]3=C4N(C=CN45)C(C)C)C=CN2...
#
#                                           SMILES 2 comments   annotator1  \
# 0                                              NaN     done          NaN
# 1                                              NaN     Done          NaN
# 2                                              NaN     Done          NaN
# 3  Fc1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4ccc2)cc1      NaN  Alex Voznyy
# 4  Fc1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4ccc2)cc1      NaN  Alex Voznyy
#
#                                 paper_url Done id_in_paper         Formula  \
# 0  https://doi.org/10.1002/adma.201505790   No          3p             NaN
# 1  https://doi.org/10.1002/adma.201505790   No          2m             NaN
# 2  https://doi.org/10.1002/adma.201505790   No  2m+solvent             NaN
# 3  https://doi.org/10.1002/adma.201505790  Yes          1m  [Ir(mimf)(L1)]
# 4  https://doi.org/10.1002/adma.201505790  Yes          1p  [Ir(pimf)(L1)]
#
#   integrating sphere or relative (for solution measurement)  \
# 0                                           relative
# 1                                                NaN
# 2                                                NaN
# 3                                           relative
# 4                                           relative
#
#   degassed or aerated? solvent  phos_emission_wavelength (nm, 77K)44  \
# 0             degassed  CH2Cl2                                   NaN
# 1             degassed  CH2Cl2                                   NaN
# 2             degassed  CH2Cl2                                   NaN
# 3             degassed  CH2Cl2                                   NaN
# 4             degassed  CH2Cl2                                   NaN
#
#   phos_emission_wavelength (nm, room temperature)  \
# 0                                   503, 537, 583
# 1                                   490, 526, 566
# 2                                   490, 526, 566
# 3                                             467
# 4                                             468
#
#    PLQY (fraction, room temperature)  PLQY film  \
# 0                               0.98        NaN
# 1                               0.92        NaN
# 2                               0.92        NaN
# 3                               0.99       0.95
# 4                               0.86       0.95
#
#    phos_lifetime (microseconds, room temperature)  EQEmax % carbene homoleptic
# 0                                        0.000003       NaN    True      False
# 1                                        0.000005       NaN    True      False
# 2                                        0.000005       NaN    True      False
# 3                                        5.410000      27.0     NaN        NaN
# 4                                        6.690000      20.8     NaN        NaN

# %%
import pandas as pd

# Assuming you've already read your data into a DataFrame named `data`
# file_path = "E:/DB for chromophore_Sci_Data_rev02.csv"
# data = pd.read_csv(file_path)

# Remove rows where 'Quantum yield' is NaN
cleaned_data = data.dropna(subset=['PLQY (fraction, room temperature)'])
cleaned_data_2 = cleaned_data.dropna(subset=['SMILES 1'])
cleaned_data_3 = cleaned_data_2.dropna(subset=['SMILES 2'])

# Remove rows where PLQY is greater than 1
cleaned_data_4 = cleaned_data_3[cleaned_data_3['PLQY (fraction, room temperature)'] <= 1]

# Display the first few rows of the cleaned dataset to verify
print(cleaned_data_4.head())
# Out:
#      entry                                           SMILES 1  \
# 3  ELOZZ1M   CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(F)(F)F)c5)C
# 4  ELOZZ1P  FC(F)(F)c1cc(N(C2=[Ir]3=C4N(C=CN45)C(C)C)C=CN2...
# 5   ELOZAI   CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(F)(F)F)c5)C
# 6  ELOZZ2P  FC(F)(F)c1cc(N(C2=[Ir]3=C4N(C=CN45)C(C)C)C=CN2...
# 7  ELOZZ3M   CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(C)(C)C)c5)C
#
#                                             SMILES 2 comments   annotator1  \
# 3    Fc1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4ccc2)cc1      NaN  Alex Voznyy
# 4    Fc1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4ccc2)cc1      NaN  Alex Voznyy
# 5  FC(F)(c1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4cc...      NaN  Alex Voznyy
# 6  FC(F)(c1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4cc...      NaN  Alex Voznyy
# 7  FC(F)(c1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4cc...      NaN  Alex Voznyy
#
#                                 paper_url Done id_in_paper         Formula  \
# 3  https://doi.org/10.1002/adma.201505790  Yes          1m  [Ir(mimf)(L1)]
# 4  https://doi.org/10.1002/adma.201505790  Yes          1p  [Ir(pimf)(L1)]
# 5  https://doi.org/10.1002/adma.201505790  Yes          2m  [Ir(mimf)(L2)]
# 6  https://doi.org/10.1002/adma.201505790  Yes          2p  [Ir(pimf)(L2)]
# 7  https://doi.org/10.1002/adma.201505790  Yes          3m  [Ir(mimb)(L2)]
#
#   integrating sphere or relative (for solution measurement)  \
# 3                                           relative
# 4                                           relative
# 5                                           relative
# 6                                           relative
# 7                                           relative
#
#   degassed or aerated? solvent  phos_emission_wavelength (nm, 77K)44  \
# 3             degassed  CH2Cl2                                   NaN
# 4             degassed  CH2Cl2                                   NaN
# 5             degassed  CH2Cl2                                   NaN
# 6             degassed  CH2Cl2                                   NaN
# 7             degassed  CH2Cl2                                   NaN
#
#   phos_emission_wavelength (nm, room temperature)  \
# 3                                             467
# 4                                             468
# 5                                             490
# 6                                             492
# 7                                             501
#
#    PLQY (fraction, room temperature)  PLQY film  \
# 3                               0.99       0.95
# 4                               0.86       0.95
# 5                               0.92       0.96
# 6                               0.80       0.89
# 7                               1.00       0.99
#
#    phos_lifetime (microseconds, room temperature)  EQEmax % carbene homoleptic
# 3                                            5.41      27.0     NaN        NaN
# 4                                            6.69      20.8     NaN        NaN
# 5                                            4.65      30.0     NaN        NaN
# 6                                            4.39      28.3     NaN        NaN
# 7                                            2.84      31.4     NaN        NaN

# %%
# Extract specific columns
#Smiles_Strings = cleaned_data[['Chromophore']]
# Assuming 'cleaned_data' is your pandas DataFrame

# Extract specific columns
Smiles_Strings = cleaned_data_4[['SMILES 1', 'SMILES 2']]

# Display the first few rows of the extracted columns to verify
print(Smiles_Strings.head())

# Display the first few rows of the extracted columns to verify
print(Smiles_Strings.head())
# Out:
#                                             SMILES 1  \
# 3   CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(F)(F)F)c5)C
# 4  FC(F)(F)c1cc(N(C2=[Ir]3=C4N(C=CN45)C(C)C)C=CN2...
# 5   CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(F)(F)F)c5)C
# 6  FC(F)(F)c1cc(N(C2=[Ir]3=C4N(C=CN45)C(C)C)C=CN2...
# 7   CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(C)(C)C)c5)C
#
#                                             SMILES 2
# 3    Fc1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4ccc2)cc1
# 4    Fc1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4ccc2)cc1
# 5  FC(F)(c1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4cc...
# 6  FC(F)(c1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4cc...
# 7  FC(F)(c1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4cc...
#                                             SMILES 1  \
# 3   CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(F)(F)F)c5)C
# 4  FC(F)(F)c1cc(N(C2=[Ir]3=C4N(C=CN45)C(C)C)C=CN2...
# 5   CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(F)(F)F)c5)C
# 6  FC(F)(F)c1cc(N(C2=[Ir]3=C4N(C=CN45)C(C)C)C=CN2...
# 7   CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(C)(C)C)c5)C
#
#                                             SMILES 2
# 3    Fc1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4ccc2)cc1
# 4    Fc1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4ccc2)cc1
# 5  FC(F)(c1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4cc...
# 6  FC(F)(c1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4cc...
# 7  FC(F)(c1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4cc...

# %% [markdown]
# More cleaning

# %%
#list used to remove faulty indices
combined_list = [24, 25, 26, 29, 30, 31, 33, 34, 35, 36, 37, 70]
combined_list2 = [18, 19, 20, 23, 24, 25, 27, 28, 29, 30, 63]

# %%
import pandas as pd

# Example: Loading cleaned_data_3 DataFrame (replace with actual loading or DataFrame creation code)
# cleaned_data_3 = pd.read_csv('path_to_your_cleaned_data_3.csv')

# Indices to remove
indices_to_remove = combined_list
# Remove the specified indices
cleaned_data_4_dropped = cleaned_data_4.drop(indices_to_remove, errors='ignore')

# If you want to reset the index afterwards (optional)
cleaned_data_4_dropped.reset_index(drop=True, inplace=True)
cleaned_data_4_dropped_2 = cleaned_data_4_dropped.drop(combined_list2, errors='ignore')

# If you want to reset the index afterwards (optional)
cleaned_data_4_dropped_2.reset_index(drop=True, inplace=True)

# %%
paper = cleaned_data_4_dropped_2[['paper_url']]

# %%
# Extract specific columns
Quantum_yield = cleaned_data_4_dropped_2[['PLQY (fraction, room temperature)']]

# Display the first few rows of the extracted columns to verify
print(Quantum_yield.head())
# Out:
#    PLQY (fraction, room temperature)
# 0                               0.99
# 1                               0.86
# 2                               0.92
# 3                               0.80
# 4                               1.00

# %%
import matplotlib.pyplot as plt
import numpy as np
# Convert QM9_properties to a NumPy array
Quantum_yield_array = np.array(Quantum_yield)

# Convert back to a list if needed
Quantum_yield_array_list = Quantum_yield_array.tolist()

# Print the filtered QM9_properties
print("Filtered QM9 Properties:", Quantum_yield_array_list[0:2])

denselayersnodes = Quantum_yield_array.shape[1]
print(denselayersnodes)
# Out:
# Filtered QM9 Properties: [[0.99], [0.86]]
# 1

# %%
print(Quantum_yield_array)
# Out:
# [[0.99 ]
#  [0.86 ]
#  [0.92 ]
#  [0.8  ]
#  [1.   ]
#  [0.98 ]
#  [1.   ]
#  [0.98 ]
#  [0.81 ]
#  [0.82 ]
#  [0.68 ]
#  [0.79 ]
#  [0.72 ]
#  [1.   ]
#  [0.92 ]
#  [0.94 ]
#  [1.   ]
#  [0.56 ]
#  [0.604]
#  [0.38 ]
#  [0.41 ]
#  [0.   ]
#  [0.   ]
#  [0.95 ]
#  [0.75 ]
#  [0.7  ]
#  [0.49 ]
#  [0.83 ]
#  [0.73 ]
#  [0.87 ]
#  [0.22 ]
#  [0.42 ]
#  [0.8  ]
#  [0.84 ]
#  [0.93 ]
#  [0.79 ]
#  [0.35 ]
#  [0.045]
#  [0.74 ]
#  [0.58 ]
#  [0.69 ]
#  [0.6  ]
#  [0.54 ]
#  [0.75 ]
#  [0.78 ]
#  [0.6  ]
#  [0.49 ]
#  [0.62 ]
#  [0.27 ]
#  [0.32 ]
#  [0.31 ]
#  [0.36 ]
#  [0.38 ]
#  [0.37 ]]

# %%
import matplotlib.pyplot as plt

# Assuming 'Quantum_yield_array' contains the data for which we need to plot the histogram
# This is a placeholder array; replace it with your actual data

# Plotting the histogram
plt.figure(figsize=(10, 6))
plt.hist(Quantum_yield_array, bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram of Quantum Yield Values')
plt.xlabel('Quantum Yield')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# Display the plot
plt.show()

# %%
# Assuming 'cleaned_data' is your pandas DataFrame and it has been cleaned/preprocessed
chromophore_smiles = cleaned_data_4_dropped_2['SMILES 1'].tolist()
solvent_smiles = cleaned_data_4_dropped_2['SMILES 2'].tolist()

# %%
from rdkit import Chem
from rdkit.Chem import AllChem

# Function to generate Morgan fingerprints
def generate_morgan_fingerprint(smiles, radius=2, num_bits=2048):
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        fingerprint = AllChem.GetMorganFingerprintAsBitVect(mol, radius, nBits=num_bits)
        return fingerprint
    else:
        return None

# Keep track of indices with faulty SMILES strings
faulty_indices = []

# Generate Morgan fingerprints for the SMILES strings
filtered_chromophore_fingerprints = []

for i, smiles in enumerate(chromophore_smiles):
    fingerprint = generate_morgan_fingerprint(smiles)
    if fingerprint is not None:
        filtered_chromophore_fingerprints.append(fingerprint)
    else:
        # Skip faulty SMILES and record the index
        faulty_indices.append(i)

# Print the content of filtered_structures_fingerprints in the specified format
print("Filtered Structures:")
for i, smiles in enumerate(chromophore_smiles):
    print(f"Entry {i + 1}: {smiles}")

# Note: Printing the fingerprints directly might not be very informative since they're binary vectors
# If you want to see them as bit strings or another format, you'd need to convert them accordingly.

# Print indices with faulty SMILES
print("Faulty Indices:", faulty_indices)
# Out:
# Filtered Structures:
# Entry 1: CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(F)(F)F)c5)C
# Entry 2: FC(F)(F)c1cc(N(C2=[Ir]3=C4N(C=CN45)C(C)C)C=CN2C(C)C)c3c5c1
# Entry 3: CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(F)(F)F)c5)C
# Entry 4: FC(F)(F)c1cc(N(C2=[Ir]3=C4N(C=CN45)C(C)C)C=CN2C(C)C)c3c5c1
# Entry 5: CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(C)(C)C)c5)C
# Entry 6: CC(C)(C)c1cc(N(C2=[Ir]3=C4N(C=CN45)C(C)C)C=CN2C(C)C)c3c5c1
# Entry 7: CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(C)(C)C)c5)C
# Entry 8: CC(C)(C)c1cc(N(C2=[Ir]3=C4N(C=CN45)C(C)C)C=CN2C(C)C)c3c5c1
# Entry 9: CN1C2=[Ir]3=C4N(C=CN4c5c3c(N2C=C1)cc(C(F)(F)F)c5)C
# Entry 10: CN1C2=[Ir]3=C4N(C=CN4c5c3c(N2C=C1)cc(C(C)(C)C)c5)C
# Entry 11: CN1C2=[Ir]3=C4N(c5c(N4c6c3c(N2c7c1cccc7)cc(C(F)(F)F)c6)cccc5)C
# Entry 12: CN1[C]2=[Ir]3=[C]4N(C)c5ccccc5N4c4cc(C(C)(C)C)cc(c43)N2c2ccccc21
# Entry 13: CN1C=CN(C1=2)c3cc(C(C)(C)C)cc4c3[Ir]2=C5N4C=CN5C
# Entry 14: CC(C)(c1cc(c2c([Ir]3n4c5cc(C(F)(F)F)n4)cc(F)cc2)[n+]3c5c1)C
# Entry 15: CC(C)(c1cc(c2n([Ir]3c4c5ccc(F)c4)nc(C(F)(F)F)c2)[n+]3c5n1)C
# Entry 16: CC(C)(c1cc(c2n([Ir]3c4c5ccc(F)c4)nc(C(F)(F)F)c2)[n+]3c5n1)C
# Entry 17: CC(C)(c1nc(c2n([Ir]3c4c5ccc(F)c4)nc(C(F)(F)F)c2)[n+]3c5c1)C
# Entry 18: CC(C)N1C=CN2[C]1=[Ir]1=[C]3N(C=CN3C(C)C)c3cc(C(C)(C)C)cc2c31
# Entry 19: CC(C)N1C=CN2[C]1=[Ir]1=[C]3N(C=CN3C(C)C)c3cc(C(F)(F)F)cc2c31
# Entry 20: CCCCN1C=CN(c2c3c4c(C)cc2C)C1=[Ir]3=C5N(C=CN45)CCCC
# Entry 21: CCCCN1C=CN(c2c3c4c(C)cc2C)C1=[Ir]3=C5N(C=CN45)CCCC
# Entry 22: CC(C)N1C=CN2[C]1=[Ir]1=[C]3N(C=CN3C(C)C)c3cc(C(F)(F)F)cc2c31
# Entry 23: CC(N1C=CN2C1=[Ir]3=C4N(c5c3c2cc(C(C)(C)C)c5)C=CN4C(C)C)C
# Entry 24: CC(N1C=CN2C1=[Ir]3=C4N(c5c3c2cc(C(F)(F)F)c5)C=CN4C(C)C)C
# Entry 25: CC(C)N1C=CN2[C]1=[Ir]1=[C]3N(C=CN3C(C)C)c3cc(C(C)(C)C)cc2c31
# Entry 26: CC(C)N1C=CN2[C]1=[Ir]1=[C]3N(C=CN3C(C)C)c3cc(C(F)(F)F)cc2c31
# Entry 27: CC(N1C=CN2C1=[Ir]3=C4N(c5c3c2cc(C(C)(C)C)c5)C=CN4C(C)C)C
# Entry 28: CC(C)N1C=CN(c2c3c4cc(C(F)(F)F)c2)C1=[Ir]3=C5N(C=CN45)C(C)C
# Entry 29:  CC(C)N1C=CN(c2c3c4cc(C(C)(C)C)c2)C1=[Ir]3=C5N(C=CN45)C(C)C
# Entry 30: CC(C)N1C=CN(c2c3c4cc(C(F)(F)F)c2)C1=[Ir]3=C5N(C=CN45)C(C)C
# Entry 31: CC(C)N1C=CN(c2c3c4cc(C(F)(F)F)c2)C1=[Ir]3=C5N(C=CN45)C(C)C
# Entry 32: CC(C)N1C=CN(c2c3c4cc(C(F)(F)F)c2)C1=[Ir]3=C5N(C=CN45)C(C)C
# Entry 33: FC(F)(c1cc2c3c(N(C=CN4C)C4=[Ir]3=C5N(C)C=CN52)c1)F
# Entry 34: FC(F)(F)c1cc(N(C2=[Ir]3=C4N(C=CN45)C(C)C)C=CN2C(C)C)c3c5c1
# Entry 35: FC(F)(F)c1cc(N(C2=[Ir]3=C4N(C=CN45)C(C)C)C=CN2C(C)C)c3c5c1
# Entry 36: FC(F)(F)c1cc(N(C2=[Ir]3=C4N(C=CN45)C(C)C)C=CN2C(C)C)c3c5c1
# Entry 37: FC(F)(F)c1cc(N(C2=[Ir]3=C4N(C=CN45)C(C)C)C=CN2C(C)C)c3c5c1
# Entry 38: CCCCN1C=CN(C1=2)c3cccc4c3[Ir]2=C5N(CCCC)C=CN45
# Entry 39: CCCCN1C=CN(C1=2)c3cccc4c3[Ir]2=C5N(CCCC)C=CN45
# Entry 40: CCCCN1C=CN(C1=2)c3cccc4c3[Ir]2=C5N(CCCC)C=CN45
# Entry 41: CCCCN1C=CN(C1=2)c3cccc4c3[Ir]2=C5N(CCCC)C=CN45
# Entry 42: CCCCN1C=CN(C1=2)c3cccc4c3[Ir]2=C5N(CCCC)C=CN45
# Entry 43: CCCCN1C=CN(C1=2)c3cccc4c3[Ir]2=C5N(CCCC)C=CN45
# Entry 44: CCCCN1C=CN(C1=2)c3cccc4c3[Ir]2=C5N(CCCC)C=CN45
# Entry 45: CCCCN1C=CN(C1=2)c3cccc4c3[Ir]2=C5N(CCCC)C=CN45
# Entry 46: CCCCN1C=CN(C1=2)c3cccc4c3[Ir]2=C5N(CCCC)C=CN45
# Entry 47: CCCCN1C=CN(C1=2)c3cccc4c3[Ir]2=C5N(CCCC)C=CN45
# Entry 48: CCCCN1C=CN(C1=2)c3cccc4c3[Ir]2=C5N(CCCC)C=CN45
# Entry 49: CCCCN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2ccc5)CCCC
# Entry 50: CCCCN1C=CN2[C]1=[Ir]1=[C]3N(CCCC)C=CN3c3cccc2c31
# Entry 51: CCCCN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2ccc5)CCCC
# Entry 52: CCCCN1C=CN2[C]1=[Ir]1=[C]3N(CCCC)C=CN3c3cccc2c31
# Entry 53: CCCCN1C=CN2[C]1=[Ir]1=[C]3N(CCCC)C=CN3c3cccc2c31
# Entry 54: CCCCN1C=CN2[C]1=[Ir]1=[C]3N(CCCC)C=CN3c3cccc2c31
# Faulty Indices: []

# %%
from rdkit import Chem
from rdkit.Chem import AllChem

# Function to generate Morgan fingerprints
def generate_morgan_fingerprint(smiles, radius=2, num_bits=2048):
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        fingerprint = AllChem.GetMorganFingerprintAsBitVect(mol, radius, nBits=num_bits)
        return fingerprint
    else:
        return None

# Keep track of indices with faulty SMILES strings
faulty_indices = []

# Generate Morgan fingerprints for the SMILES strings
filtered_solvent_smiles_fingerprints = []

for i, smiles in enumerate(solvent_smiles):
    fingerprint = generate_morgan_fingerprint(smiles)
    if fingerprint is not None:
        filtered_solvent_smiles_fingerprints.append(fingerprint)
    else:
        # Skip faulty SMILES and record the index
        faulty_indices.append(i)

# Print the content of filtered_structures_fingerprints in the specified format
print("Filtered Structures:")
for i, smiles in enumerate(solvent_smiles):
    print(f"Entry {i + 1}: {smiles}")

# Note: Printing the fingerprints directly might not be very informative since they're binary vectors
# If you want to see them as bit strings or another format, you'd need to convert them accordingly.

# Print indices with faulty SMILES
print("Faulty Indices:", faulty_indices)
# Out:
# Filtered Structures:
# Entry 1: Fc1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4ccc2)cc1
# Entry 2: Fc1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4ccc2)cc1
# Entry 3: FC(F)(c1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4ccc2)cc1)F
# Entry 4: FC(F)(c1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4ccc2)cc1)F
# Entry 5: FC(F)(c1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4ccc2)cc1)F
# Entry 6: FC(F)(c1ccc(c2[n+]([Ir]n3c4cc(C(F)(F)F)n3)c4ccc2)cc1)F
# Entry 7: FC(F)(F)c1cc(c2[n+]([Ir]3)c(c4ccccc4)cc5c2C=CC=C5)n3n1
# Entry 8: FC(F)(F)c1cc(c2[n+]([Ir]3)c(c4ccccc4)cc5c2C=CC=C5)n3n1
# Entry 9: Fc1cc([Ir]2n3c(c4[n+]2c(O5)ccc4)cc(C(F)(F)F)n3)c5cc1
# Entry 10: Fc1cc([Ir]2n3c(c4[n+]2c(O5)ccc4)cc(C(F)(F)F)n3)c5cc1
# Entry 11: Fc1ccc2c(c1)[Ir]1n3nc(C(F)(F)F)cc3-c3cccc([n+]31)O2
# Entry 12: Fc1ccc2c(c1)[Ir]1n3nc(C(F)(F)F)cc3-c3cccc([n+]31)O2
# Entry 13: FC(F)(c1nn2c(c3cc(C(C)(C)C)cc4[n+]3[Ir]2c5c(O4)ccc(F)c5)c1)F
# Entry 14: CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(C)(C)C)c5)C
# Entry 15: CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(C)(C)C)c5)C
# Entry 16: CN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(F)(F)F)c5)C
# Entry 17: CCCCN1C=CN2C1=[Ir]3=C4N(C=CN4c5c3c2cc(C(F)(F)F)c5)CCCC
# Entry 18: C1=CC2=C(C=C1)[Ir]4[N+]3=C2C=CC=C3C5=NC6=C([N]45)C=CC=C6
# Entry 19: COc1cc2[n+]3c(N(C4=C(OC)C=CC=C45)c6c5cc(OC)cc6[Ir]3N7C2=CC(C(F)(F)F)=N7)c1
# Entry 20: CCCCN1C=CN2[C]1=[Ir]1=[C]3N(CCCC)C=CN3c3c(C)cc(C)c2c31
# Entry 21: CCCCN1C=CN2[C]1=[Ir]1=[C]3N(CCCC)C=CN3c3c(C)cc(C)c2c31
# Entry 22: FC(F)(F)c1cc2n(n1)[Ir]1n3nc(C(F)(F)F)cc3-c3cccc-2[n+]31
# Entry 23: FC(F)(c1nn([Ir]2n3c(c4[n+]2c5ccc4)cc(C(F)(F)F)n3)c5c1)F
# Entry 24: Fc1cc(F)c2c(c1)[Ir]1n3nc(C(F)(F)F)cc3-c3cccc-2[n+]31
# Entry 25: Fc1cc(F)c2c(c1)[Ir]1n3nc(C(F)(F)F)cc3-c3cccc-2[n+]31
# Entry 26: Fc1cc(F)c2c(c1)[Ir]1c3cc(F)cc(F)c3-c3cccc-2[n+]31
# Entry 27: Fc1cc(F)c2c(c1)[Ir]1c3cc(F)cc(F)c3-c3cccc-2[n+]31
# Entry 28: FC(F)(F)c1cc(c2[n+]3c(N4c5c(c6c4c([Ir]37)cc(C(F)(F)F)c6)cc(C(F)(F)F)cc5)cc(C(C)(C)C)c2)n7n1
# Entry 29: COc1cc(N2c3c(c4c2c([Ir]5n6c7cc(C(F)(F)F)n6)cc(OC)c4)cccc3OC)[n+]5c7c1
# Entry 30: COc1cccc2c1N3c4cc(N(C)C)cc5[n+]4[Ir](n6c5cc(C(F)(F)F)n6)c7c3c2cc(OC)c7
# Entry 31: COc1cccc2c1N3c4cc(N(C)C)cc5[n+]4[Ir](n6c5cc(C(F)(F)F)n6)c7c3c2cc(OC)c7
# Entry 32: COc1cccc2c1N3c4cc(OC)cc5[n+]4[Ir](n6c5nc(C(F)(F)F)n6)c7c3c2cc(OC)c7
# Entry 33: FC(F)(F)c1nn2c(c3[n+]([Ir]24)c(C5(C)c6ccccc6c7cccc4c57)cc(C(C)(C)C)c3)c1
# Entry 34: FC(F)(F)c1nn2c(c3[n+]([Ir]24)c(C5(C)c6ccccc6c7cccc4c57)cc(C(C)(C)C)c3)c1
# Entry 35: FC(F)(F)c1nn2c(c3[n+]([Ir]24)c(C5(C)c6ccccc6c7cccc4c57)cc(C(C)(C)C)c3)n1
# Entry 36: FC(F)(F)c1nn2c(c3[n+]([Ir]24)c(C5(C)c6ccccc6c7cccc4c57)cc(OC)c3)c1
# Entry 37: FC(F)(F)c1nn2c(c3[n+]([Ir]24)c(C5(C)c6ccccc6c7cccc4c57)cc(N8CCCC8)c3)c1
# Entry 38: Br[Ir]1[n+]2ccccc2c3ccccc13
# Entry 39: N#C[Ir]1[n+]2ccccc2c3ccccc13
# Entry 40: N#CO[Ir]1[n+]2ccccc2c3ccccc13
# Entry 41: Br[Ir]1[n+]2ccccc2C3=C1C=CS3
# Entry 42: N#C[Ir]1[n+]2ccccc2C3=C1C=CS3
# Entry 43: N#CO[Ir]1[n+]2ccccc2C3=C1C=CS3
# Entry 44: Br[Ir]1[n+]2c(C=CC=C3)c3c(C)cc2C4=C1C=CS4
# Entry 45: Cc1cc(C2=C3C=CS2)[n+]([Ir]3C#N)c4c1C=CC=C4
# Entry 46: Br[Ir]1[N+]2=C(C3=C(C=C2)C=CC=C3)C4=C1C=CS4
# Entry 47: N#C[Ir]1[N+]2=C(C3=C1C=CS3)C4=C(C=CC=C4)C=C2
# Entry 48: N#CO[Ir]1[N+]2=C(C3=C(C=C2)C=CC=C3)C4=C1C=CS4
# Entry 49: Br[Ir](c1c2sc3ccccc13)[n+]4c2sc5c4cccc5
# Entry 50: N#C[Ir]([n+]1c2ccccc2sc13)c(c3s4)c5c4cccc5
# Entry 51: N#CO[Ir](c1c2sc3ccccc13)[n+]4c2sc5c4cccc5
# Entry 52: Cc1c(C)cc(N2C(N(c3c2nccc3)C)=[Ir]4)c4c1
# Entry 53: Cc1c(C)cc(N2C(N(c3c2nccc3)C)=[Ir]4)c4c1C
# Entry 54: Cc1c(C)cc(N2C(N(c3c2nccc3)Cc4ccccc4)=[Ir]5)c5c1C
# Faulty Indices: []

# %%
# Assuming filtered_chromophore_fingerprints and filtered_solvent_fingerprints
# contain fingerprint bit strings of the same length and are aligned

combined_fingerprints = []

for chromophore_fp, solvent_fp in zip(filtered_chromophore_fingerprints, filtered_solvent_smiles_fingerprints):
    # For bit strings, concatenation can be done directly with the + operator
    combined_fp = chromophore_fp + solvent_fp
    combined_fingerprints.append(combined_fp)

# Now combined_fingerprints contains the concatenated fingerprints

# %%
import numpy as np
structures_fp_array = np.array(combined_fingerprints)
structures_fp_array.shape
print(structures_fp_array.shape)
# Out:
# (54, 4096)

# %%
# Plotting the histogram of the log-plus-one transformed quantum yields
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(Quantum_yield_array, bins=20, color='purple', alpha=0.7)
plt.title('Histogram of Quantum Yields')
plt.xlabel('Log-plus-one Transformed Value')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, BatchNormalization, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping
from tensorflow.keras.metrics import MeanAbsoluteError
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import LambdaLR
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, BatchNormalization, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from keras import backend as K

# %%
len(structures_fp_array)
# Out:
# 54

# %%
paper_array = np.unique(paper)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test, paper_train, paper_test = train_test_split(
    structures_fp_array, Quantum_yield_array, paper,
    test_size=0.2, random_state=42
)

# Reshape the input data for LSTM
X_train_reshaped = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_reshaped = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# %%
print(paper_test)
# Out:
#                                         paper_url
# 19              https://doi.org/10.1021/ic302695q
# 49             https://doi.org/10.1039/D1SC01426A
# 48             https://doi.org/10.1039/D1SC01426A
# 12         https://doi.org/10.1002/adma.201702464
# 44             https://doi.org/10.1039/D1SC01426A
# 5          https://doi.org/10.1002/adma.201505790
# 17  https://doi.org/10.1021/acs.organomet.9b00265
# 52             https://doi.org/10.1039/D2TC02829H
# 3          https://doi.org/10.1002/adma.201505790
# 32             https://doi.org/10.1039/D0TC05218C
# 13  https://doi.org/10.1021/acs.chemmater.8b04278

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, BatchNormalization, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping
from tensorflow.keras.metrics import MeanAbsoluteError
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import LambdaLR
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, BatchNormalization, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from keras import backend as K


model = Sequential()
# Replacing Bidirectional LSTM with Unidirectional LSTM
model.add(LSTM(300, activation="relu", return_sequences=True, input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2])))
model.add(Dropout(0.4))  # Add dropout with a rate of 40%
model.add(LSTM(300, activation="relu", return_sequences=True))
model.add(Dropout(0.1))  # Add dropout with a rate of 10%
model.add(LSTM(200, activation="relu"))  # Fixed missing comma here
# Uncomment if using GlobalMaxPooling1D
# model.add(GlobalMaxPooling1D(data_format='channels_last'))

# Initialize the optimizer
optimizer = Adam(learning_rate=0.001)

# Assuming 'denselayersnodes' is defined elsewhere as the number of nodes in your final Dense layer
model.add(Dense(denselayersnodes, activation=None))  # Use 'sigmoid' for binary outcomes

# Compile the model
model.compile(loss='mse', optimizer=optimizer, metrics=['mae'])

# Define the learning rate scheduler
def lr_schedule(epoch):
    return 0.001 * (0.9 ** epoch)

lr_scheduler = LearningRateScheduler(lr_schedule)

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=300, restore_best_weights=True)

# Train the model
history = model.fit(X_train_reshaped, y_train, epochs=20000, batch_size=32, validation_split=0.2, callbacks=[lr_scheduler, early_stopping])
# Out:
# Epoch 1/20000
# /home/kinkini/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.5174 - mae: 0.6675 - val_loss: 0.1751 - val_mae: 0.4010 - learning_rate: 0.0010
# Epoch 2/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.4805 - mae: 0.6426 - val_loss: 0.1625 - val_mae: 0.3852 - learning_rate: 9.0000e-04
# Epoch 3/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4539 - mae: 0.6241 - val_loss: 0.1449 - val_mae: 0.3621 - learning_rate: 8.1000e-04
# Epoch 4/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4278 - mae: 0.6082 - val_loss: 0.1215 - val_mae: 0.3289 - learning_rate: 7.2900e-04
# Epoch 5/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3566 - mae: 0.5521 - val_loss: 0.0921 - val_mae: 0.2821 - learning_rate: 6.5610e-04
# Epoch 6/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2778 - mae: 0.4849 - val_loss: 0.0585 - val_mae: 0.2171 - learning_rate: 5.9049e-04
# Epoch 7/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1834 - mae: 0.3933 - val_loss: 0.0270 - val_mae: 0.1302 - learning_rate: 5.3144e-04
# Epoch 8/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1061 - mae: 0.2931 - val_loss: 0.0092 - val_mae: 0.0826 - learning_rate: 4.7830e-04
# Epoch 9/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1035 - mae: 0.2591 - val_loss: 0.0141 - val_mae: 0.0964 - learning_rate: 4.3047e-04
# Epoch 10/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1718 - mae: 0.3174 - val_loss: 0.0200 - val_mae: 0.1157 - learning_rate: 3.8742e-04
# Epoch 11/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1560 - mae: 0.3014 - val_loss: 0.0172 - val_mae: 0.1051 - learning_rate: 3.4868e-04
# Epoch 12/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0806 - mae: 0.2052 - val_loss: 0.0131 - val_mae: 0.0932 - learning_rate: 3.1381e-04
# Epoch 13/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0589 - mae: 0.1699 - val_loss: 0.0105 - val_mae: 0.0819 - learning_rate: 2.8243e-04
# Epoch 14/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0538 - mae: 0.1695 - val_loss: 0.0095 - val_mae: 0.0769 - learning_rate: 2.5419e-04
# Epoch 15/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0482 - mae: 0.1821 - val_loss: 0.0093 - val_mae: 0.0754 - learning_rate: 2.2877e-04
# Epoch 16/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0505 - mae: 0.1815 - val_loss: 0.0094 - val_mae: 0.0759 - learning_rate: 2.0589e-04
# Epoch 17/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0486 - mae: 0.1856 - val_loss: 0.0097 - val_mae: 0.0779 - learning_rate: 1.8530e-04
# Epoch 18/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0513 - mae: 0.1868 - val_loss: 0.0101 - val_mae: 0.0803 - learning_rate: 1.6677e-04
# Epoch 19/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0406 - mae: 0.1656 - val_loss: 0.0107 - val_mae: 0.0832 - learning_rate: 1.5009e-04
# Epoch 20/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0420 - mae: 0.1700 - val_loss: 0.0115 - val_mae: 0.0871 - learning_rate: 1.3509e-04
# Epoch 21/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0446 - mae: 0.1578 - val_loss: 0.0124 - val_mae: 0.0912 - learning_rate: 1.2158e-04
# Epoch 22/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0407 - mae: 0.1630 - val_loss: 0.0132 - val_mae: 0.0943 - learning_rate: 1.0942e-04
# Epoch 23/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0388 - mae: 0.1536 - val_loss: 0.0138 - val_mae: 0.0965 - learning_rate: 9.8477e-05
# Epoch 24/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0451 - mae: 0.1635 - val_loss: 0.0143 - val_mae: 0.0985 - learning_rate: 8.8629e-05
# Epoch 25/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0433 - mae: 0.1706 - val_loss: 0.0148 - val_mae: 0.1001 - learning_rate: 7.9766e-05
# Epoch 26/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0439 - mae: 0.1756 - val_loss: 0.0151 - val_mae: 0.1010 - learning_rate: 7.1790e-05
# Epoch 27/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0444 - mae: 0.1765 - val_loss: 0.0154 - val_mae: 0.1020 - learning_rate: 6.4611e-05
# Epoch 28/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0364 - mae: 0.1506 - val_loss: 0.0157 - val_mae: 0.1028 - learning_rate: 5.8150e-05
# Epoch 29/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0450 - mae: 0.1667 - val_loss: 0.0156 - val_mae: 0.1024 - learning_rate: 5.2335e-05
# Epoch 30/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0386 - mae: 0.1593 - val_loss: 0.0154 - val_mae: 0.1016 - learning_rate: 4.7101e-05
# Epoch 31/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0369 - mae: 0.1493 - val_loss: 0.0152 - val_mae: 0.1011 - learning_rate: 4.2391e-05
# Epoch 32/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0379 - mae: 0.1565 - val_loss: 0.0151 - val_mae: 0.1007 - learning_rate: 3.8152e-05
# Epoch 33/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0410 - mae: 0.1587 - val_loss: 0.0151 - val_mae: 0.1007 - learning_rate: 3.4337e-05
# Epoch 34/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0439 - mae: 0.1647 - val_loss: 0.0152 - val_mae: 0.1009 - learning_rate: 3.0903e-05
# Epoch 35/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0355 - mae: 0.1392 - val_loss: 0.0152 - val_mae: 0.1012 - learning_rate: 2.7813e-05
# Epoch 36/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0411 - mae: 0.1582 - val_loss: 0.0154 - val_mae: 0.1018 - learning_rate: 2.5032e-05
# Epoch 37/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0441 - mae: 0.1696 - val_loss: 0.0157 - val_mae: 0.1026 - learning_rate: 2.2528e-05
# Epoch 38/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0350 - mae: 0.1454 - val_loss: 0.0158 - val_mae: 0.1030 - learning_rate: 2.0276e-05
# Epoch 39/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0369 - mae: 0.1503 - val_loss: 0.0159 - val_mae: 0.1032 - learning_rate: 1.8248e-05
# Epoch 40/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0392 - mae: 0.1507 - val_loss: 0.0159 - val_mae: 0.1032 - learning_rate: 1.6423e-05
# Epoch 41/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0410 - mae: 0.1599 - val_loss: 0.0159 - val_mae: 0.1032 - learning_rate: 1.4781e-05
# Epoch 42/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0397 - mae: 0.1478 - val_loss: 0.0158 - val_mae: 0.1031 - learning_rate: 1.3303e-05
# Epoch 43/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0447 - mae: 0.1667 - val_loss: 0.0158 - val_mae: 0.1030 - learning_rate: 1.1973e-05
# Epoch 44/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0397 - mae: 0.1544 - val_loss: 0.0158 - val_mae: 0.1030 - learning_rate: 1.0775e-05
# Epoch 45/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0317 - mae: 0.1400 - val_loss: 0.0158 - val_mae: 0.1031 - learning_rate: 9.6977e-06
# Epoch 46/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0391 - mae: 0.1477 - val_loss: 0.0158 - val_mae: 0.1030 - learning_rate: 8.7280e-06
# Epoch 47/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0382 - mae: 0.1531 - val_loss: 0.0157 - val_mae: 0.1028 - learning_rate: 7.8552e-06
# Epoch 48/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0399 - mae: 0.1459 - val_loss: 0.0157 - val_mae: 0.1026 - learning_rate: 7.0697e-06
# Epoch 49/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0415 - mae: 0.1560 - val_loss: 0.0157 - val_mae: 0.1026 - learning_rate: 6.3627e-06
# Epoch 50/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0356 - mae: 0.1415 - val_loss: 0.0157 - val_mae: 0.1026 - learning_rate: 5.7264e-06
# Epoch 51/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0462 - mae: 0.1667 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 5.1538e-06
# Epoch 52/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0384 - mae: 0.1483 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.6384e-06
# Epoch 53/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0378 - mae: 0.1421 - val_loss: 0.0158 - val_mae: 0.1028 - learning_rate: 4.1746e-06
# Epoch 54/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0387 - mae: 0.1497 - val_loss: 0.0158 - val_mae: 0.1028 - learning_rate: 3.7571e-06
# Epoch 55/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0420 - mae: 0.1562 - val_loss: 0.0158 - val_mae: 0.1028 - learning_rate: 3.3814e-06
# Epoch 56/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0384 - mae: 0.1454 - val_loss: 0.0158 - val_mae: 0.1028 - learning_rate: 3.0433e-06
# Epoch 57/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0375 - mae: 0.1509 - val_loss: 0.0158 - val_mae: 0.1028 - learning_rate: 2.7389e-06
# Epoch 58/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0367 - mae: 0.1438 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.4650e-06
# Epoch 59/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0355 - mae: 0.1391 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.2185e-06
# Epoch 60/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0347 - mae: 0.1477 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.9967e-06
# Epoch 61/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0409 - mae: 0.1496 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.7970e-06
# Epoch 62/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0418 - mae: 0.1570 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.6173e-06
# Epoch 63/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0435 - mae: 0.1604 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 1.4556e-06
# Epoch 64/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0403 - mae: 0.1555 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 1.3100e-06
# Epoch 65/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0387 - mae: 0.1572 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 1.1790e-06
# Epoch 66/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0363 - mae: 0.1385 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 1.0611e-06
# Epoch 67/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0437 - mae: 0.1620 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 9.5500e-07
# Epoch 68/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0384 - mae: 0.1451 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 8.5950e-07
# Epoch 69/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0410 - mae: 0.1524 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 7.7355e-07
# Epoch 70/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0377 - mae: 0.1524 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 6.9620e-07
# Epoch 71/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0381 - mae: 0.1513 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 6.2658e-07
# Epoch 72/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0370 - mae: 0.1400 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 5.6392e-07
# Epoch 73/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0446 - mae: 0.1690 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 5.0753e-07
# Epoch 74/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0344 - mae: 0.1404 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 4.5678e-07
# Epoch 75/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0377 - mae: 0.1475 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 4.1110e-07
# Epoch 76/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0412 - mae: 0.1526 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 3.6999e-07
# Epoch 77/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0445 - mae: 0.1675 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 3.3299e-07
# Epoch 78/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0311 - mae: 0.1418 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 2.9969e-07
# Epoch 79/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0372 - mae: 0.1452 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 2.6972e-07
# Epoch 80/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0418 - mae: 0.1588 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 2.4275e-07
# Epoch 81/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0394 - mae: 0.1488 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 2.1847e-07
# Epoch 82/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0359 - mae: 0.1470 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 1.9663e-07
# Epoch 83/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0375 - mae: 0.1465 - val_loss: 0.0157 - val_mae: 0.1027 - learning_rate: 1.7696e-07
# Epoch 84/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0342 - mae: 0.1486 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.5927e-07
# Epoch 85/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0376 - mae: 0.1496 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.4334e-07
# Epoch 86/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0397 - mae: 0.1536 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.2901e-07
# Epoch 87/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0407 - mae: 0.1575 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.1611e-07
# Epoch 88/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0375 - mae: 0.1508 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.0450e-07
# Epoch 89/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0372 - mae: 0.1532 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 9.4046e-08
# Epoch 90/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0336 - mae: 0.1390 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 8.4641e-08
# Epoch 91/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0398 - mae: 0.1506 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 7.6177e-08
# Epoch 92/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0377 - mae: 0.1494 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 6.8560e-08
# Epoch 93/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0377 - mae: 0.1473 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 6.1704e-08
# Epoch 94/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0357 - mae: 0.1447 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.5533e-08
# Epoch 95/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0360 - mae: 0.1430 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.9980e-08
# Epoch 96/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0442 - mae: 0.1594 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.4982e-08
# Epoch 97/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0362 - mae: 0.1455 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.0484e-08
# Epoch 98/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0372 - mae: 0.1517 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.6435e-08
# Epoch 99/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0437 - mae: 0.1622 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.2792e-08
# Epoch 100/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0358 - mae: 0.1421 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.9513e-08
# Epoch 101/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0385 - mae: 0.1494 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.6561e-08
# Epoch 102/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0363 - mae: 0.1506 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.3905e-08
# Epoch 103/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0343 - mae: 0.1438 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.1515e-08
# Epoch 104/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0357 - mae: 0.1478 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.9363e-08
# Epoch 105/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0365 - mae: 0.1442 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.7427e-08
# Epoch 106/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0363 - mae: 0.1517 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.5684e-08
# Epoch 107/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0408 - mae: 0.1536 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.4116e-08
# Epoch 108/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0309 - mae: 0.1218 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.2704e-08
# Epoch 109/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0345 - mae: 0.1375 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.1434e-08
# Epoch 110/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0400 - mae: 0.1568 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.0290e-08
# Epoch 111/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0385 - mae: 0.1512 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 9.2614e-09
# Epoch 112/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0396 - mae: 0.1578 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 8.3352e-09
# Epoch 113/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0402 - mae: 0.1542 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 7.5017e-09
# Epoch 114/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0363 - mae: 0.1448 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 6.7516e-09
# Epoch 115/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0370 - mae: 0.1543 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 6.0764e-09
# Epoch 116/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0330 - mae: 0.1393 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.4688e-09
# Epoch 117/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0370 - mae: 0.1464 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.9219e-09
# Epoch 118/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0377 - mae: 0.1404 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.4297e-09
# Epoch 119/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0346 - mae: 0.1395 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.9867e-09
# Epoch 120/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0370 - mae: 0.1469 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.5881e-09
# Epoch 121/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0404 - mae: 0.1505 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.2292e-09
# Epoch 122/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0353 - mae: 0.1472 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.9063e-09
# Epoch 123/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0350 - mae: 0.1366 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.6157e-09
# Epoch 124/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0378 - mae: 0.1480 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.3541e-09
# Epoch 125/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0434 - mae: 0.1555 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.1187e-09
# Epoch 126/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0437 - mae: 0.1568 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.9068e-09
# Epoch 127/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0376 - mae: 0.1488 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.7162e-09
# Epoch 128/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0382 - mae: 0.1481 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.5445e-09
# Epoch 129/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0361 - mae: 0.1392 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.3901e-09
# Epoch 130/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0355 - mae: 0.1503 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.2511e-09
# Epoch 131/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0352 - mae: 0.1416 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.1260e-09
# Epoch 132/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0311 - mae: 0.1370 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.0134e-09
# Epoch 133/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0424 - mae: 0.1541 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 9.1203e-10
# Epoch 134/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0395 - mae: 0.1526 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 8.2083e-10
# Epoch 135/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0394 - mae: 0.1523 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 7.3875e-10
# Epoch 136/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0404 - mae: 0.1528 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 6.6487e-10
# Epoch 137/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0365 - mae: 0.1508 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.9839e-10
# Epoch 138/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0336 - mae: 0.1350 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.3855e-10
# Epoch 139/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0384 - mae: 0.1515 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.8469e-10
# Epoch 140/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0400 - mae: 0.1545 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.3622e-10
# Epoch 141/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0411 - mae: 0.1594 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.9260e-10
# Epoch 142/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0372 - mae: 0.1523 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.5334e-10
# Epoch 143/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0436 - mae: 0.1602 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.1801e-10
# Epoch 144/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0324 - mae: 0.1386 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.8621e-10
# Epoch 145/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0386 - mae: 0.1463 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.5759e-10
# Epoch 146/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0358 - mae: 0.1420 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.3183e-10
# Epoch 147/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0366 - mae: 0.1459 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.0864e-10
# Epoch 148/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0397 - mae: 0.1475 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.8778e-10
# Epoch 149/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0392 - mae: 0.1576 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.6900e-10
# Epoch 150/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0389 - mae: 0.1517 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.5210e-10
# Epoch 151/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0338 - mae: 0.1433 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.3689e-10
# Epoch 152/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0376 - mae: 0.1444 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.2320e-10
# Epoch 153/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0309 - mae: 0.1293 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.1088e-10
# Epoch 154/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0358 - mae: 0.1466 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 9.9794e-11
# Epoch 155/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0384 - mae: 0.1385 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 8.9814e-11
# Epoch 156/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0382 - mae: 0.1475 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 8.0833e-11
# Epoch 157/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0336 - mae: 0.1374 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 7.2750e-11
# Epoch 158/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0384 - mae: 0.1550 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 6.5475e-11
# Epoch 159/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0381 - mae: 0.1471 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.8927e-11
# Epoch 160/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0368 - mae: 0.1486 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.3035e-11
# Epoch 161/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0381 - mae: 0.1510 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.7731e-11
# Epoch 162/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0431 - mae: 0.1632 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.2958e-11
# Epoch 163/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0381 - mae: 0.1552 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.8662e-11
# Epoch 164/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0434 - mae: 0.1711 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.4796e-11
# Epoch 165/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0343 - mae: 0.1390 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.1316e-11
# Epoch 166/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0377 - mae: 0.1550 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.8185e-11
# Epoch 167/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0522 - mae: 0.1721 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.5366e-11
# Epoch 168/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0394 - mae: 0.1540 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.2830e-11
# Epoch 169/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0343 - mae: 0.1443 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.0547e-11
# Epoch 170/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0446 - mae: 0.1598 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.8492e-11
# Epoch 171/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0440 - mae: 0.1623 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.6643e-11
# Epoch 172/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0469 - mae: 0.1668 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.4979e-11
# Epoch 173/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0421 - mae: 0.1580 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.3481e-11
# Epoch 174/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0366 - mae: 0.1529 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.2133e-11
# Epoch 175/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0362 - mae: 0.1449 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.0919e-11
# Epoch 176/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0396 - mae: 0.1549 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 9.8274e-12
# Epoch 177/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0383 - mae: 0.1565 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 8.8447e-12
# Epoch 178/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0429 - mae: 0.1634 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 7.9602e-12
# Epoch 179/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0411 - mae: 0.1533 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 7.1642e-12
# Epoch 180/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0374 - mae: 0.1468 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 6.4478e-12
# Epoch 181/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0393 - mae: 0.1492 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.8030e-12
# Epoch 182/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0391 - mae: 0.1488 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.2227e-12
# Epoch 183/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0314 - mae: 0.1264 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.7004e-12
# Epoch 184/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0398 - mae: 0.1568 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.2304e-12
# Epoch 185/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0369 - mae: 0.1398 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.8073e-12
# Epoch 186/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0402 - mae: 0.1595 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.4266e-12
# Epoch 187/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0405 - mae: 0.1517 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.0839e-12
# Epoch 188/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0393 - mae: 0.1470 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.7756e-12
# Epoch 189/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0386 - mae: 0.1553 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.4980e-12
# Epoch 190/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0444 - mae: 0.1631 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.2482e-12
# Epoch 191/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0340 - mae: 0.1438 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.0234e-12
# Epoch 192/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0352 - mae: 0.1351 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.8210e-12
# Epoch 193/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0415 - mae: 0.1543 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.6389e-12
# Epoch 194/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0413 - mae: 0.1571 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.4750e-12
# Epoch 195/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0358 - mae: 0.1372 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.3275e-12
# Epoch 196/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0391 - mae: 0.1539 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.1948e-12
# Epoch 197/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0383 - mae: 0.1567 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.0753e-12
# Epoch 198/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0378 - mae: 0.1532 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 9.6777e-13
# Epoch 199/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0402 - mae: 0.1623 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 8.7100e-13
# Epoch 200/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0308 - mae: 0.1297 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 7.8390e-13
# Epoch 201/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0382 - mae: 0.1497 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 7.0551e-13
# Epoch 202/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0388 - mae: 0.1567 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 6.3496e-13
# Epoch 203/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0334 - mae: 0.1449 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.7146e-13
# Epoch 204/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0411 - mae: 0.1511 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.1432e-13
# Epoch 205/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0368 - mae: 0.1459 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.6288e-13
# Epoch 206/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0415 - mae: 0.1640 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.1660e-13
# Epoch 207/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0429 - mae: 0.1604 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.7494e-13
# Epoch 208/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0367 - mae: 0.1428 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.3744e-13
# Epoch 209/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0379 - mae: 0.1399 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.0370e-13
# Epoch 210/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0426 - mae: 0.1673 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.7333e-13
# Epoch 211/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0391 - mae: 0.1478 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.4600e-13
# Epoch 212/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0400 - mae: 0.1590 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.2140e-13
# Epoch 213/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0342 - mae: 0.1449 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.9926e-13
# Epoch 214/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0405 - mae: 0.1542 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.7933e-13
# Epoch 215/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0391 - mae: 0.1573 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.6140e-13
# Epoch 216/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0390 - mae: 0.1521 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.4526e-13
# Epoch 217/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0395 - mae: 0.1534 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.3073e-13
# Epoch 218/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0459 - mae: 0.1611 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.1766e-13
# Epoch 219/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0444 - mae: 0.1575 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.0589e-13
# Epoch 220/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0395 - mae: 0.1547 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 9.5304e-14
# Epoch 221/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0351 - mae: 0.1351 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 8.5773e-14
# Epoch 222/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0329 - mae: 0.1446 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 7.7196e-14
# Epoch 223/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0390 - mae: 0.1505 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 6.9476e-14
# Epoch 224/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0422 - mae: 0.1565 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 6.2529e-14
# Epoch 225/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0355 - mae: 0.1439 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.6276e-14
# Epoch 226/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0472 - mae: 0.1592 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.0648e-14
# Epoch 227/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0399 - mae: 0.1540 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.5583e-14
# Epoch 228/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0365 - mae: 0.1487 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.1025e-14
# Epoch 229/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0390 - mae: 0.1557 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.6923e-14
# Epoch 230/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0355 - mae: 0.1483 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.3230e-14
# Epoch 231/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0332 - mae: 0.1317 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.9907e-14
# Epoch 232/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0371 - mae: 0.1422 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.6917e-14
# Epoch 233/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0309 - mae: 0.1323 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.4225e-14
# Epoch 234/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0342 - mae: 0.1427 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.1802e-14
# Epoch 235/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0433 - mae: 0.1681 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.9622e-14
# Epoch 236/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0384 - mae: 0.1470 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.7660e-14
# Epoch 237/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0398 - mae: 0.1465 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.5894e-14
# Epoch 238/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0356 - mae: 0.1387 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.4305e-14
# Epoch 239/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0391 - mae: 0.1560 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.2874e-14
# Epoch 240/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0390 - mae: 0.1519 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.1587e-14
# Epoch 241/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0364 - mae: 0.1370 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.0428e-14
# Epoch 242/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0396 - mae: 0.1489 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 9.3852e-15
# Epoch 243/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0458 - mae: 0.1592 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 8.4467e-15
# Epoch 244/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0350 - mae: 0.1435 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 7.6020e-15
# Epoch 245/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0380 - mae: 0.1523 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 6.8418e-15
# Epoch 246/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0427 - mae: 0.1625 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 6.1576e-15
# Epoch 247/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0431 - mae: 0.1557 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.5419e-15
# Epoch 248/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0354 - mae: 0.1367 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.9877e-15
# Epoch 249/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0446 - mae: 0.1716 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.4889e-15
# Epoch 250/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0360 - mae: 0.1531 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.0400e-15
# Epoch 251/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0343 - mae: 0.1373 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.6360e-15
# Epoch 252/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0393 - mae: 0.1522 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.2724e-15
# Epoch 253/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0383 - mae: 0.1496 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.9452e-15
# Epoch 254/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0385 - mae: 0.1549 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.6507e-15
# Epoch 255/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0397 - mae: 0.1516 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.3856e-15
# Epoch 256/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0323 - mae: 0.1290 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.1470e-15
# Epoch 257/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0406 - mae: 0.1576 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.9323e-15
# Epoch 258/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0392 - mae: 0.1489 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.7391e-15
# Epoch 259/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0317 - mae: 0.1317 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.5652e-15
# Epoch 260/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0399 - mae: 0.1548 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.4087e-15
# Epoch 261/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0350 - mae: 0.1499 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.2678e-15
# Epoch 262/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0365 - mae: 0.1450 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.1410e-15
# Epoch 263/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0372 - mae: 0.1498 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.0269e-15
# Epoch 264/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0463 - mae: 0.1689 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 9.2423e-16
# Epoch 265/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0382 - mae: 0.1579 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 8.3181e-16
# Epoch 266/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0397 - mae: 0.1515 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 7.4863e-16
# Epoch 267/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0315 - mae: 0.1314 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 6.7376e-16
# Epoch 268/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0403 - mae: 0.1462 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 6.0639e-16
# Epoch 269/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0412 - mae: 0.1567 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.4575e-16
# Epoch 270/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0436 - mae: 0.1608 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.9117e-16
# Epoch 271/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0364 - mae: 0.1440 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.4206e-16
# Epoch 272/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0378 - mae: 0.1514 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.9785e-16
# Epoch 273/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0382 - mae: 0.1469 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.5807e-16
# Epoch 274/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0351 - mae: 0.1410 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.2226e-16
# Epoch 275/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0357 - mae: 0.1417 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.9003e-16
# Epoch 276/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0353 - mae: 0.1383 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.6103e-16
# Epoch 277/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0338 - mae: 0.1387 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.3493e-16
# Epoch 278/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0375 - mae: 0.1496 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.1143e-16
# Epoch 279/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0347 - mae: 0.1420 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.9029e-16
# Epoch 280/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0391 - mae: 0.1432 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.7126e-16
# Epoch 281/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0463 - mae: 0.1783 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.5414e-16
# Epoch 282/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0397 - mae: 0.1542 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.3872e-16
# Epoch 283/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0410 - mae: 0.1582 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.2485e-16
# Epoch 284/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0389 - mae: 0.1522 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.1236e-16
# Epoch 285/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0424 - mae: 0.1594 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.0113e-16
# Epoch 286/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0359 - mae: 0.1494 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 9.1015e-17
# Epoch 287/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0411 - mae: 0.1499 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 8.1914e-17
# Epoch 288/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0409 - mae: 0.1545 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 7.3723e-17
# Epoch 289/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0425 - mae: 0.1635 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 6.6350e-17
# Epoch 290/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0299 - mae: 0.1327 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.9715e-17
# Epoch 291/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0439 - mae: 0.1683 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 5.3744e-17
# Epoch 292/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0326 - mae: 0.1369 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.8369e-17
# Epoch 293/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0385 - mae: 0.1590 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 4.3532e-17
# Epoch 294/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0346 - mae: 0.1376 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.9179e-17
# Epoch 295/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0329 - mae: 0.1323 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.5261e-17
# Epoch 296/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0474 - mae: 0.1634 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 3.1735e-17
# Epoch 297/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0448 - mae: 0.1659 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.8562e-17
# Epoch 298/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0458 - mae: 0.1732 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.5705e-17
# Epoch 299/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0439 - mae: 0.1701 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.3135e-17
# Epoch 300/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0367 - mae: 0.1461 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 2.0821e-17
# Epoch 301/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0365 - mae: 0.1454 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.8739e-17
# Epoch 302/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0402 - mae: 0.1527 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.6865e-17
# Epoch 303/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0424 - mae: 0.1484 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.5179e-17
# Epoch 304/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0418 - mae: 0.1560 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.3661e-17
# Epoch 305/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0353 - mae: 0.1413 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.2295e-17
# Epoch 306/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0355 - mae: 0.1557 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 1.1065e-17
# Epoch 307/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0358 - mae: 0.1456 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 9.9588e-18
# Epoch 308/20000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0434 - mae: 0.1628 - val_loss: 0.0158 - val_mae: 0.1027 - learning_rate: 8.9629e-18

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error

# Make predictions on the test set
y_pred = model.predict(X_test_reshaped)

# Scatter plot of actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.5, s=10)  # Use a smaller marker size with s=10
plt.title('Actual vs. Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)  # Diagonal line

# Calculate R² and MAE
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# Add a text box with R² and MAE values
textstr = f'$R^2={r2:.2f}$\n$MAE={mae:.2f}$'
# Position: right top corner
plt.text(0.95, 0.05, textstr, transform=plt.gca().transAxes, fontsize=14,
         verticalalignment='bottom', horizontalalignment='right',
         bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

plt.show()

# Display R² and MAE in the console as well
print(f'R²: {r2}')
print(f'Mean Absolute Error (MAE): {mae}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# R²: -2.181102838709767
# Mean Absolute Error (MAE): 0.3671120948791504

# %%
import os

import tensorflow as tf
from tensorflow import keras

print(tf.version.VERSION)
# Load the model
new_model = tf.keras.models.load_model('E:/PLQY_ORIG.keras')

# Show the model architecture
new_model.summary()
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error
# Out:
# 2.16.1
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_13 (LSTM)                  │ (None, 1, 200)         │     3,437,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 1, 200)         │           800 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_14 (LSTM)                  │ (None, 1, 200)         │       320,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 1, 200)         │           800 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_15 (LSTM)                  │ (None, 200)            │       320,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 200)            │           800 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │           201 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,243,005 (46.70 MB)
#  Trainable params: 4,080,601 (15.57 MB)
#  Non-trainable params: 1,200 (4.69 KB)
#  Optimizer params: 8,161,204 (31.13 MB)
